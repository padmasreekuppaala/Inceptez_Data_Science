# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Auto.csv')

# %%
df.shape
# Out:
# (205, 26)

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration num_doors  \
# 0          3                NaN  alfa-romero       gas        std       two
# 1          3                NaN  alfa-romero       gas        std       two
# 2          1                NaN  alfa-romero       gas        std       two
# 3          2              164.0         audi       gas        std      four
# 4          2              164.0         audi       gas        std      four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.price.max()
# Out:
# 45400.0

# %%
#Find the most expensive car company name
df.loc[df['price'] == df.price.max()]
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 74          1                NaN  mercedes-benz       gas        std
#
#    num_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 74       two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 74          304         mpfi   3.8    3.35               8.0      184.0
#
#     peak_rpm city_mpg  highway_mpg    price
# 74    4500.0       14           16  45400.0
#
# [1 rows x 26 columns]

# %%
#Count total cars per company
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %%
#Find each company’s highest price car
df.groupby(['make'])['price'].agg('max')
# Out:
# make
# alfa-romero      16500.0
# audi             23875.0
# bmw              41315.0
# chevrolet         6575.0
# dodge            12964.0
# honda            12945.0
# isuzu            11048.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mercury          16503.0
# mitsubishi       14869.0
# nissan           19699.0
# peugot           18150.0
# plymouth         12764.0
# porsche          37028.0
# renault           9895.0
# saab             18620.0
# subaru           11694.0
# toyota           17669.0
# volkswagen       13845.0
# volvo            22625.0
# Name: price, dtype: float64

# %%
#Sort all cars by Price column
df.sort_values(by=['price'])
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 138          2               83.0         subaru       gas        std
# 18           2              121.0      chevrolet       gas        std
# 50           1              104.0          mazda       gas        std
# 150          1               87.0         toyota       gas        std
# 76           2              161.0     mitsubishi       gas        std
# ..         ...                ...            ...       ...        ...
# 74           1                NaN  mercedes-benz       gas        std
# 9            0                NaN           audi       gas      turbo
# 44           1                NaN          isuzu       gas        std
# 45           0                NaN          isuzu       gas        std
# 129          1                NaN        porsche       gas        std
#
#     num_doors body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized_losses    float64
# make                  object
# fuel_type             object
# aspiration            object
# num_doors             object
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_cylinders         object
# engine_size            int64
# fuel_system           object
# bore                 float64
# stroke               float64
# compression_ratio    float64
# horsepower           float64
# peak_rpm             float64
# city_mpg               int64
# highway_mpg            int64
# price                float64
# dtype: object

# %%
#Group by make, fuel-type and body-style to calculate the average of city-mpg and highwaympg (miles per gallon)
df.groupby(['make', 'fuel_type'])['city-mpg'].avg()
df.groupby(['make', 'fuel_type'])['highway_mpg'].avg()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\UMASHA~1\AppData\Local\Temp/ipykernel_18632/206347793.py in <module>
#       1 #Group by make, fuel-type and body-style to calculate the average of city-mpg and highwaympg (miles per gallon)
# ----> 2 df.groupby(['make', 'fuel_type'])['city-mpg'].avg()
#       3 df.groupby(['make', 'fuel_type'])['highway_mpg'].avg()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
# ...

# %%
df.groupby(['make','fuel_type])['price'].agg('max')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\UMASHA~1\AppData\Local\Temp/ipykernel_18632/1202098882.py in <module>
# ----> 1 df.groupby(['body-style'])['price'].agg('max')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     887             from pandas.core.groupby.grouper import get_grouper
#     888
# ...
